# %%
# %% [markdown]
# # Credit Scoring Model Evaluation with XGBoost
# 
# **Comparison of three training strategies:**
# 1. Original imbalanced data → Default XGBoost
# 2. SMOTE‑balanced training data → Default XGBoost
# 3. cWGAN‑GP balanced data → **Optuna‑tuned XGBoost (5‑fold CV)**
# 
# **Classifier:** XGBoost
# **Evaluation metrics:** AUC, Recall, Precision, F1, Accuracy

# %%
# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2

# %%
# %% [markdown]
# ## 1. Imports and Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix, classification_report, roc_curve
)
from imblearn.over_sampling import SMOTE
import joblib
import sys
import os
import warnings
warnings.filterwarnings('ignore')

# Add scripts folder to path
sys.path.append(os.path.abspath("../scripts"))

# Import custom training module
from train_xgboost import train_xgboost_default, train_xgboost_optuna
from explainability import shap_explain, shap_waterfall_plot
from evaluation import (
    evaluate_classifier,
    compare_all_models,
    shap_evaluation,
    nested_cv_evaluation,
    friedman_test,
    wilcoxon_test
)

sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (8, 5)

# %%
# %% [markdown]
# ## 2. Load Datasets

# %%
# Load imbalanced original data (one‑hot encoded)
df_imb = pd.read_csv("../data/processed/default_credit_onehot.csv")
print("Imbalanced data shape:", df_imb.shape)
print("Class counts:\n", df_imb['Class'].value_counts())

# Load cWGAN‑GP balanced data
df_gan = pd.read_csv("../data/processed/default_credit_balanced_cwgan_improved.csv")
print("\ncWGAN‑GP balanced data shape:", df_gan.shape)
print("Class counts:\n", df_gan['Class'].value_counts())

target_col = 'Class'
# Out:
# Imbalanced data shape: (30000, 52)
# Class counts:
#  Class
# 0    23364
# 1     6636
# Name: count, dtype: int64
#
# cWGAN‑GP balanced data shape: (46728, 52)
# Class counts:
#  Class
# 1    23364
# 0    23364
# Name: count, dtype: int64

# %%
# %% [markdown]
# ## 3. Split Imbalanced Data (70% train / 30% test)

# %%
X = df_imb.drop(columns=[target_col])
y = df_imb[target_col]

X_train_imb, X_test_imb, y_train_imb, y_test_imb = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

print(f"Train size: {X_train_imb.shape[0]}, Test size: {X_test_imb.shape[0]}")
print("Train class distribution:\n", y_train_imb.value_counts())
print("Test class distribution:\n", y_test_imb.value_counts())
# Out:
# Train size: 21000, Test size: 9000
# Train class distribution:
#  Class
# 0    16355
# 1     4645
# Name: count, dtype: int64
# Test class distribution:
#  Class
# 0    7009
# 1    1991
# Name: count, dtype: int64

# %%
# %% [markdown]
# ## 4. Prepare SMOTE‑Balanced Training Set

# %%
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train_imb, y_train_imb)

print("SMOTE balanced training set shape:", X_train_smote.shape)
print("SMOTE balanced class distribution:\n", pd.Series(y_train_smote).value_counts())
# Out:
# SMOTE balanced training set shape: (32710, 51)
# SMOTE balanced class distribution:
#  Class
# 0    16355
# 1    16355
# Name: count, dtype: int64

# %%
# %% [markdown]
# ## 5. Split cWGAN‑GP Balanced Data (70% train / 30% test)

# %%
X_gan = df_gan.drop(columns=[target_col])
y_gan = df_gan[target_col]

X_train_gan, X_test_gan, y_train_gan, y_test_gan = train_test_split(
    X_gan, y_gan, test_size=0.3, random_state=42, stratify=y_gan
)

print(f"Train size: {X_train_gan.shape[0]}, Test size: {X_test_gan.shape[0]}")
print("Train class distribution:\n", y_train_gan.value_counts())
print("Test class distribution:\n", y_test_gan.value_counts())
# Out:
# Train size: 32709, Test size: 14019
# Train class distribution:
#  Class
# 1    16355
# 0    16354
# Name: count, dtype: int64
# Test class distribution:
#  Class
# 0    7010
# 1    7009
# Name: count, dtype: int64

# %%
# %% [markdown]
# ## 6. Train Models

# %%
# =====================================================================
# Model 1: Imbalanced Baseline (Default XGBoost)
# =====================================================================
print("\n" + "="*60)
print("MODEL 1: IMBALANCED BASELINE")
print("="*60)

best_imb = train_xgboost_default(
    X_train_imb.values, y_train_imb.values,
    X_test_imb.values, y_test_imb.values,
    scale_pos_weight=True
)
# Out:
# ============================================================
# MODEL 1: IMBALANCED BASELINE
# ============================================================
#   Default XGBoost trained (scale_pos_weight=3.52)

# %%
# =====================================================================
# Model 2: SMOTE Baseline (Default XGBoost)
# =====================================================================
print("\n" + "="*60)
print("MODEL 2: SMOTE BASELINE")
print("="*60)

# Convert SMOTE output back to DataFrame with feature names
X_train_smote = pd.DataFrame(X_train_smote, columns=X_train_imb.columns)

best_smote = train_xgboost_default(
    X_train_smote.values, y_train_smote,
    X_test_imb.values, y_test_imb.values,
    scale_pos_weight=False
)
# Out:
# ============================================================
# MODEL 2: SMOTE BASELINE
# ============================================================
#   Default XGBoost trained (scale_pos_weight=1.00)

# %%
# =====================================================================
# Model 3: cWGAN‑GP (Optuna‑tuned XGBoost with 5‑fold CV)
# =====================================================================
print("\n" + "="*60)
print("MODEL 3: cWGAN‑GP (PROPOSED)")
print("="*60)

best_gan, best_params_gan = train_xgboost_optuna(
    X_train_gan.values, y_train_gan.values,
    X_test_gan.values, y_test_gan.values,
    n_trials=50,
    cv_folds=5,
    random_state=42
)

# Save model for SHAP
joblib.dump(best_gan, '../models/xgb_cwgan_default_credit_balanced.pkl')
print("\n✅ Model saved to ../models/xgb_cwgan_default_credit_balanced.pkl")
# Out:
# ============================================================
# MODEL 3: cWGAN‑GP (PROPOSED)
# ============================================================
#
#   Starting Optuna hyperparameter optimization
#   Trials: 50, CV folds: 5
# [I 2026-05-02 18:02:01,868] A new study created in memory with name: no-name-98162586-6294-4d25-a8aa-5ce54c8b4843
#   0%|          | 0/50 [00:02<?, ?it/s]
# [I 2026-05-02 18:02:21,284] Trial 0 finished with value: 0.9351613379680618 and parameters: {'n_estimators': 144, 'max_depth': 10, 'learning_rate': 0.1205712628744377, 'subsample': 0.8394633936788146, 'colsample_bytree': 0.6624074561769746, 'min_child_weight': 2, 'gamma': 0.2904180608409973, 'reg_alpha': 8.661761457749352, 'reg_lambda': 6.011150117432088}. Best is trial 0 with value: 0.9351613379680618.
# [I 2026-05-02 18:02:27,043] Trial 1 finished with value: 0.9348482824979574 and parameters: {'n_estimators': 227, 'max_depth': 3, 'learning_rate': 0.2708160864249968, 'subsample': 0.9329770563201687, 'colsample_bytree': 0.6849356442713105, 'min_child_weight': 2, 'gamma': 0.9170225492671691, 'reg_alpha': 3.0424224295953772, 'reg_lambda': 5.247564316322379}. Best is trial 0 with value: 0.9351613379680618.
# [I 2026-05-02 18:02:31,699] Trial 2 finished with value: 0.9362661289132305 and parameters: {'n_estimators': 158, 'max_depth': 5, 'learning_rate': 0.08012737503998542, 'subsample': 0.6557975442608167, 'colsample_bytree': 0.7168578594140873, 
and parameters: {'n_estimators': 300, 'max_depth': 8, 'learning_rate': 0.030183958462683666, 'subsample': 0.600751747415686, 'colsample_bytree': 0.8313116742128104, 'min_child_weight': 7, 'gamma': 1.2077746649016994, 'reg_alpha': 5.911429522235765, 'reg_lambda': 3.899826721786607}. Best is trial 10 with value: 0.9367190817231432.
# [I 2026-05-02 18:04:22,712] Trial 14 finished with value: 0.9368502596243127 and parameters: {'n_estimators': 257, 'max_depth': 7, 'learning_rate': 0.030178130912072224, 'subsample': 0.9984067957444853, 'colsample_bytree': 0.9983997994537456, 'min_child_weight': 9, 'gamma': 2.7939929152165717, 'reg_alpha': 5.878957013846386, 'reg_lambda': 4.2106345049298115}. Best is trial 14 with value: 0.9368502596243127.
# [I 2026-05-02 18:04:30,938] Trial 15 finished with value: 0.9369121078238661 and parameters: {'n_estimators': 258, 'max_depth': 7, 'learning_rate': 0.038401878173509305, 'subsample': 0.9750244637464088, 'colsample_bytree': 0.982227285427502, 'min_child_weight': 10, 'gamma': 3.018006210136393, 'reg_alpha': 3.8422274169371162, 'reg_lambda': 4.023051386247598}. Best is trial 15 with value: 0.9369121078238661.
# [I 2026-05-02 18:04:38,047] Trial 16 finished with value: 0.9367648156423293 and parameters: {'n_estimators': 251, 'max_depth': 6, 'learning_rate': 0.04475745984779072, 'subsample': 0.9946602206724103, 'colsample_bytree': 0.990624430147067, 'min_child_weight': 10, 'gamma': 2.820010260156588, 'reg_alpha': 6.592455552427123, 'reg_lambda': 0.13179214380923554}. Best is trial 15 with value: 0.9369121078238661.
# [I 2026-05-02 18:04:46,968] Trial 17 finished with value: 0.9366657843632916 and parameters: {'n_estimators': 253, 'max_depth': 7, 'learning_rate': 0.03693846794034179, 'subsample': 0.9925238264497515, 'colsample_bytree': 0.986732237824015, 'min_child_weight': 9, 'gamma': 3.5688876705438823, 'reg_alpha': 0.3630481323211834, 'reg_lambda': 3.4136106497647374}. Best is trial 15 with value: 0.9369121078238661.
# [I 2026-05-02 18:04:55,653] Trial 18 finished with value: 0.9363158179677367 and parameters: {'n_estimators': 250, 'max_depth': 6, 'learning_rate': 0.01732660203378892, 'subsample': 0.9299305629337544, 'colsample_bytree': 0.9276269504938003, 'min_child_weight': 9, 'gamma': 4.171793334781645, 'reg_alpha': 2.291555862559637, 'reg_lambda': 0.7181787039901035}. Best is trial 15 with value: 0.9369121078238661.
# [I 2026-05-02 18:04:58,668] Trial 19 finished with value: 0.9365365195404316 and parameters: {'n_estimators': 97, 'max_depth': 7, 'learning_rate': 0.19912661867540798, 'subsample': 0.9475198718806054, 'colsample_bytree': 0.8752346920085474, 'min_child_weight': 9, 'gamma': 2.7128866027301815, 'reg_alpha': 4.181540822820742, 'reg_lambda': 4.419276406617247}. Best is trial 15 with value: 0.9369121078238661.
# [I 2026-05-02 18:05:07,514] Trial 20 finished with value: 0.9368060191925078 and parameters: {'n_estimators': 268, 'max_depth': 9, 'learning_rate': 0.03888971138369911, 'subsample': 0.8868325109157882, 'colsample_bytree': 0.9582098693870196, 'min_child_weight': 10, 'gamma': 3.245096647257674, 'reg_alpha': 6.5724156638757725, 'reg_lambda': 9.938427850497087}. Best is trial 15 with value: 0.9369121078238661.
# [I 2026-05-02 18:05:16,360] Trial 21 finished with value: 0.9368390291967945 and parameters: {'n_estimators': 268, 'max_depth': 10, 'learning_rate': 0.04769693248351427, 'subsample': 0.8862998427321271, 'colsample_bytree': 0.9617201563269553, 'min_child_weight': 10, 'gamma': 3.11909493432656, 'reg_alpha': 6.856895930089276, 'reg_lambda': 5.410226467135134}. Best is trial 15 with value: 0.9369121078238661.
# [I 2026-05-02 18:05:25,309] Trial 22 finished with value: 0.9369737874902218 and parameters: {'n_estimators': 234, 'max_depth': 9, 'learning_rate': 0.04398189955114846, 'subsample': 0.9682294642346347, 'colsample_bytree': 0.9628575997817183, 'min_child_weight': 8, 'gamma': 2.327122497128112, 'reg_alpha': 5.260075541055258, 'reg_lambda': 5.37028776359543}. Best is trial 22 with value: 0.9369737874902218.
# [I 2026-05-02 18:05:38,721] Trial 23 finished with value: 0.9364802495425005 and parameters: {'n_estimators': 232, 'max_depth': 9, 'learning_rate': 0.01732222734737367, 'subsample': 0.9646870235812794, 'colsample_bytree': 0.9958989774894627, 'min_child_weight': 8, 'gamma': 2.369474934278951, 'reg_alpha': 5.030911215349642, 'reg_lambda': 3.1244051753314483}. Best is trial 22 with value: 0.9369737874902218.
# [I 2026-05-02 18:05:44,659] Trial 24 finished with value: 0.9368397322487573 and parameters: {'n_estimators': 187, 'max_depth': 6, 'learning_rate': 0.06915549141659373, 'subsample': 0.9774224016850367, 'colsample_bytree': 0.8946787020276512, 'min_child_weight': 8, 'gamma': 2.2971798704516413, 'reg_alpha': 3.5407440599654008, 'reg_lambda': 4.11523670840079}. Best is trial 22 with value: 0.9369737874902218.
# [I 2026-05-02 18:05:53,766] Trial 25 finished with value: 0.9361091297768326 and parameters: {'n_estimators': 274, 'max_depth': 4, 'learning_rate': 0.03347881587754358, 'subsample': 0.9095874165790645, 'colsample_bytree': 0.9449137241747024, 'min_child_weight': 6, 'gamma': 2.808245858888184, 'reg_alpha': 5.430641746961818, 'reg_lambda': 5.74355159054577}. Best is trial 22 with value: 0.9369737874902218.
# [I 2026-05-02 18:06:03,535] Trial 26 finished with value: 0.936522678356039 and parameters: {'n_estimators': 229, 'max_depth': 7, 'learning_rate': 0.018455040499717662, 'subsample': 0.9609397968344494, 'colsample_bytree': 0.8660698517703787, 'min_child_weight': 9, 'gamma': 3.6266540392700697, 'reg_alpha': 2.038074810865208, 'reg_lambda': 3.5776043590341926}. Best is trial 22 with value: 0.9369737874902218.
# [I 2026-05-02 18:06:13,705] Trial 27 finished with value: 0.9366587765977166 and parameters: {'n_estimators': 248, 'max_depth': 9, 'learning_rate': 0.04749547935835156, 'subsample': 0.913893989816756, 'colsample_bytree': 0.9650029771434478, 'min_child_weight': 8, 'gamma': 1.9353412781085613, 'reg_alpha': 4.493683107488106, 'reg_lambda': 4.810116109725274}. Best is trial 22 with value: 0.9369737874902218.
# [I 2026-05-02 18:06:27,181] Trial 28 finished with value: 0.9369044574256155 and parameters: {'n_estimators': 269, 'max_depth': 8, 'learning_rate': 0.023727425436159636, 'subsample': 0.8627785923424292, 'colsample_bytree': 0.7828436536165113, 'min_child_weight': 6, 'gamma': 4.24832359844582, 'reg_alpha': 3.453096674872426, 'reg_lambda': 2.672092586521857}. Best is trial 22 with value: 0.9369737874902218.
# [I 2026-05-02 18:06:34,564] Trial 29 finished with value: 0.9367131025945762 and parameters: {'n_estimators': 279, 'max_depth': 9, 'learning_rate': 0.1592172820823658, 'subsample': 0.8387713155683338, 'colsample_bytree': 0.7426654546934841, 'min_child_weight': 6, 'gamma': 4.355181199275245, 'reg_alpha': 3.3894523120526596, 'reg_lambda': 1.4063812727736984}. Best is trial 22 with value: 0.9369737874902218.
# [I 2026-05-02 18:06:54,275] Trial 30 finished with value: 0.9324005799620491 and parameters: {'n_estimators': 235, 'max_depth': 10, 'learning_rate': 0.07894219216069215, 'subsample': 0.7656722053911771, 'colsample_bytree': 0.7847628828612986, 'min_child_weight': 5, 'gamma': 0.6155467087603381, 'reg_alpha': 1.8181930630870147, 'reg_lambda': 2.6104435789462106}. Best is trial 22 with value: 0.9369737874902218.
# [I 2026-05-02 18:07:04,749] Trial 31 finished with value: 0.9367157401184038 and parameters: {'n_estimators': 263, 'max_depth': 8, 'learning_rate': 0.024131599395104678, 'subsample': 0.8514107577606862, 'colsample_bytree': 0.7631317828357674, 'min_child_weight': 9, 'gamma': 4.348658639034384, 'reg_alpha': 4.9840112172640945, 'reg_lambda': 5.992395100136745}. Best is trial 22 with value: 0.9369737874902218.
# [I 2026-05-02 18:07:13,073] Trial 32 finished with value: 0.9368134701776712 and parameters: {'n_estimators': 214, 'max_depth': 7, 'learning_rate': 0.03123584317226542, 'subsample': 0.9972080759300875, 'colsample_bytree': 0.9402617837562588, 'min_child_weight': 3, 'gamma': 3.5986631117606613, 'reg_alpha': 3.9045127293674415, 'reg_lambda': 2.9893080847456535}. Best is trial 22 with value: 0.9369737874902218.
# [I 2026-05-02 18:07:20,510] Trial 33 finished with value: 0.9370688198636111 and parameters: {'n_estimators': 240, 'max_depth': 8, 'learning_rate': 0.04063635966608058, 'subsample': 0.9434569565426306, 'colsample_bytree': 0.8649158040589953, 'min_child_weight': 6, 'gamma': 2.5457248340734115, 'reg_alpha': 6.154559397574556, 'reg_lambda': 4.8857010193370325}. Best is trial 33 with value: 0.9370688198636111.
# [I 2026-05-02 18:07:27,314] Trial 34 finished with value: 0.9370005348020115 and parameters: {'n_estimators': 191, 'max_depth': 8, 'learning_rate': 0.05303107321244726, 'subsample': 0.9388097441361205, 'colsample_bytree': 0.8582808080352902, 'min_child_weight': 6, 'gamma': 2.1316161625838594, 'reg_alpha': 7.682470802422098, 'reg_lambda': 5.01683695214639}. Best is trial 33 with value: 0.9370688198636111.
# [I 2026-05-02 18:07:32,787] Trial 35 finished with value: 0.936930042657203 and parameters: {'n_estimators': 173, 'max_depth': 9, 'learning_rate': 0.09186856913939093, 'subsample': 0.9422593788434209, 'colsample_bytree': 0.8657239010790555, 'min_child_weight': 5, 'gamma': 2.116960693803113, 'reg_alpha': 7.832449249862239, 'reg_lambda': 5.120513603395984}. Best is trial 33 with value: 0.9370688198636111.
# [I 2026-05-02 18
. Best is trial 33 with value: 0.9370688198636111.
# [I 2026-05-02 18:08:28,979] Trial 45 finished with value: 0.9355708252730469 and parameters: {'n_estimators': 114, 'max_depth': 8, 'learning_rate': 0.29342267840395536, 'subsample': 0.9263163504293673, 'colsample_bytree': 0.8489704658337254, 'min_child_weight': 4, 'gamma': 1.8187762685250828, 'reg_alpha': 8.312481500560198, 'reg_lambda': 6.160265197593877}. Best is trial 33 with value: 0.9370688198636111.
# [I 2026-05-02 18:08:37,917] Trial 46 finished with value: 0.9367858220242834 and parameters: {'n_estimators': 208, 'max_depth': 10, 'learning_rate': 0.045241981545406054, 'subsample': 0.8655934434613499, 'colsample_bytree': 0.8103073310354288, 'min_child_weight': 3, 'gamma': 2.4775926137100197, 'reg_alpha': 9.232470371148384, 'reg_lambda': 4.454187185567931}. Best is trial 33 with value: 0.9370688198636111.
# [I 2026-05-02 18:08:47,546] Trial 47 finished with value: 0.9368807876532103 and parameters: {'n_estimators': 223, 'max_depth': 9, 'learning_rate': 0.06651849426230493, 'subsample': 0.9005786780572307, 'colsample_bytree': 0.8832826514661343, 'min_child_weight': 6, 'gamma': 2.13065361703004, 'reg_alpha': 7.151368730327379, 'reg_lambda': 7.785909337327777}. Best is trial 33 with value: 0.9370688198636111.
# [I 2026-05-02 18:08:53,532] Trial 48 finished with value: 0.9368464238441664 and parameters: {'n_estimators': 150, 'max_depth': 8, 'learning_rate': 0.08205271867676889, 'subsample': 0.9502029147221891, 'colsample_bytree': 0.8427691754865808, 'min_child_weight': 5, 'gamma': 2.575802832141893, 'reg_alpha': 8.117141145965487, 'reg_lambda': 5.3468809345025905}. Best is trial 33 with value: 0.9370688198636111.
# [I 2026-05-02 18:09:02,754] Trial 49 finished with value: 0.9368456868883488 and parameters: {'n_estimators': 180, 'max_depth': 9, 'learning_rate': 0.05300745750937149, 'subsample': 0.7324426163210918, 'colsample_bytree': 0.8653264562454638, 'min_child_weight': 7, 'gamma': 3.026563596553037, 'reg_alpha': 6.042992368347172, 'reg_lambda': 4.682209384967435}. Best is trial 33 with value: 0.9370688198636111.
#
#   Best CV AUC-ROC: 0.9371
#   Best hyperparameters:
#     n_estimators: 240
#     max_depth: 8
#     learning_rate: 0.04063635966608058
#     subsample: 0.9434569565426306
#     colsample_bytree: 0.8649158040589953
#     min_child_weight: 6
#     gamma: 2.5457248340734115
#     reg_alpha: 6.154559397574556
#     reg_lambda: 4.8857010193370325
#
# ✅ Model saved to ../models/xgb_cwgan_default_credit_balanced.pkl

# %%
# %% [markdown]
# ## 7. Evaluate All Models

# %%
# Build models dictionary for comparison
models_dict = {
    'Imbalanced': (best_imb, X_test_imb, y_test_imb),
    'SMOTE': (best_smote, X_test_imb, y_test_imb),
    'cWGAN-GP (Optuna)': (best_gan, X_test_gan, y_test_gan)
}

# Run comprehensive comparison
results_df = compare_all_models(models_dict)
# Out:
# ==================================================
# Imbalanced Performance
# ==================================================
#   AUC-ROC: 0.7730
#   Recall: 0.5937
#   Precision: 0.4709
#   F1-score: 0.5252
#   Accuracy: 0.7626
# ==================================================
# SMOTE Performance
# ==================================================
#   AUC-ROC: 0.7718
#   Recall: 0.3908
#   Precision: 0.6320
#   F1-score: 0.4829
#   Accuracy: 0.8149
# ==================================================
# cWGAN-GP (Optuna) Performance
# ==================================================
#   AUC-ROC: 0.9394
#   Recall: 0.8254
#   Precision: 0.9362
#   F1-score: 0.8773
#   Accuracy: 0.8846
# ============================================================
# FINAL COMPARISON TABLE
# ============================================================
#                    AUC-ROC  Recall  Precision  F1-score  Accuracy
# Model
# Imbalanced          0.7730  0.5937     0.4709    0.5252    0.7626
# SMOTE               0.7718  0.3908     0.6320    0.4829    0.8149
# cWGAN-GP (Optuna)   0.9394  0.8254     0.9362    0.8773    0.8846

# %%
# %% [markdown]
# ## 8. Detailed Classification Reports

# %%
print("\nImbalanced Model - Classification Report:")
print(classification_report(y_test_imb, best_imb.predict(X_test_imb), target_names=['Good', 'Bad']))

print("\nSMOTE Model - Classification Report:")
print(classification_report(y_test_imb, best_smote.predict(X_test_imb), target_names=['Good', 'Bad']))

print("\ncWGAN‑GP Model - Classification Report:")
print(classification_report(y_test_gan, best_gan.predict(X_test_gan), target_names=['Good', 'Bad']))
# Out:
# Imbalanced Model - Classification Report:
#               precision    recall  f1-score   support
#
#         Good       0.88      0.81      0.84      7009
#          Bad       0.47      0.59      0.53      1991
#
#     accuracy                           0.76      9000
#    macro avg       0.67      0.70      0.68      9000
# weighted avg       0.79      0.76      0.77      9000
#
#
# SMOTE Model - Classification Report:
#               precision    recall  f1-score   support
#
#         Good       0.84      0.94      0.89      7009
#          Bad       0.63      0.39      0.48      1991
#
#     accuracy                           0.81      9000
#    macro avg       0.74      0.66      0.69      9000
# weighted avg       0.80      0.81      0.80      9000
#
#
# cWGAN‑GP Model - Classification Report:
#               precision    recall  f1-score   support
#
#         Good       0.84      0.94      0.89      7010
#          Bad       0.94      0.83      0.88      7009
#
#     accuracy                           0.88     14019
#    macro avg       0.89      0.88      0.88     14019
# weighted avg       0.89      0.88      0.88     14019

# %%
# %% [markdown]
# ## 9. SHAP Explainability (KernelExplainer)



# Load model and data
model = joblib.load('../models/xgb_cwgan_default_credit_balanced.pkl')
X_test = pd.read_csv('../data/processed/default_credit_balanced_cwgan_improved.csv').drop('Class', axis=1)

# Run SHAP analysis
shap_values, explainer = shap_explain(
    model=model,
    X_train=X_train_gan.values,
    X_test=X_test.values,
    feature_names=X_test.columns.tolist(),
    max_display=20,
    save_path='../figures/shap'
)

# Optional: Waterfall plot for a specific sample
shap_waterfall_plot(
    model=model,
    X_sample=X_test.values,
    feature_names=X_test.columns.tolist(),
    sample_idx=0,
    save_path='../figures/shap'
)
# Out:
# ============================================================
# SHAP EXPLAINABILITY ANALYSIS
# ============================================================
#
# Attempting TreeExplainer...
#   Booster config patched successfully.
#   TreeExplainer failed: could not convert string to float: '[5.0001526E-1]'
#   Falling back to KernelExplainer...
#   KernelExplainer created successfully.
#   Computing SHAP values for 500 samples...
#   0%|          | 0/500 [00:00<?, ?it/s]
#   SHAP values computed. Shape: (500, 51)
#
#   Generating SHAP bar plot...
#   Generating SHAP beeswarm plot...
#   Top 10 Most Important Features (by mean |SHAP value|):
#   --------------------------------------------------
#    1. PAY_0                                   : 0.0791
#    2. PAY_AMT2                                : 0.0486
#    3. PAY_2                                   : 0.0351
#    4. PAY_AMT1                                : 0.0350
#    5. BILL_AMT3                               : 0.0286
#    6. PAY_3                                   : 0.0180
#    7. LIMIT_BAL                               : 0.0146
#    8. PAY_4                                   : 0.0134
#    9. BILL_AMT1                               : 0.0131
#   10. BILL_AMT2                               : 0.0119
#
# ✅ SHAP analysis complete.
#
#   Generating SHAP waterfall plot for sample 0...
#   0%|          | 0/1 [00:00<?, ?it/s]
