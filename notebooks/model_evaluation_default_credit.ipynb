# %%
# %% [markdown]
# # Credit Scoring Model Evaluation with XGBoost
# 
# **Comparison of three training strategies:**
# 1. Original imbalanced data → Default XGBoost
# 2. SMOTE‑balanced training data → Default XGBoost
# 3. cWGAN‑GP balanced data → **Optuna‑tuned XGBoost (5‑fold CV)**
# 
# **Classifier:** XGBoost
# **Evaluation metrics:** AUC, Recall, Precision, F1, Accuracy

# %%
# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
# %% [markdown]
# ## 1. Imports and Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix, classification_report, roc_curve
)
from imblearn.over_sampling import SMOTE
import joblib
import sys
import os
import warnings
warnings.filterwarnings('ignore')

# Add scripts folder to path
sys.path.append(os.path.abspath("../scripts"))

# Import custom training module
from train_xgboost1 import train_xgboost_default, train_xgboost_optuna
from explainability import shap_explain, shap_waterfall_plot
from evaluation import *

sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (8, 5)

# %%
# %% [markdown]
# ## 2. Load Datasets

# %%
# Load imbalanced original data (one‑hot encoded)
df_imb = pd.read_csv("../data/processed/default_credit_onehot.csv")
print("Imbalanced data shape:", df_imb.shape)
print("Class counts:\n", df_imb['Class'].value_counts())

# Load cWGAN‑GP balanced data
df_gan = pd.read_csv("../data/processed/default_credit_balanced_cwgan_improved.csv")
print("\ncWGAN‑GP balanced data shape:", df_gan.shape)
print("Class counts:\n", df_gan['Class'].value_counts())

target_col = 'Class'
# Out:
# Imbalanced data shape: (30000, 52)
# Class counts:
#  Class
# 0    23364
# 1     6636
# Name: count, dtype: int64
#
# cWGAN‑GP balanced data shape: (46728, 52)
# Class counts:
#  Class
# 1    23364
# 0    23364
# Name: count, dtype: int64

# %%
# %% [markdown]
# ## 3. Split Imbalanced Data (70% train / 30% test)

# %%
X = df_imb.drop(columns=[target_col])
y = df_imb[target_col]

X_train_imb, X_test_imb, y_train_imb, y_test_imb = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

print(f"Train size: {X_train_imb.shape[0]}, Test size: {X_test_imb.shape[0]}")
print("Train class distribution:\n", y_train_imb.value_counts())
print("Test class distribution:\n", y_test_imb.value_counts())
# Out:
# Train size: 21000, Test size: 9000
# Train class distribution:
#  Class
# 0    16355
# 1     4645
# Name: count, dtype: int64
# Test class distribution:
#  Class
# 0    7009
# 1    1991
# Name: count, dtype: int64

# %%
# %% [markdown]
# ## 4. Prepare SMOTE‑Balanced Training Set

# %%
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train_imb, y_train_imb)

print("SMOTE balanced training set shape:", X_train_smote.shape)
print("SMOTE balanced class distribution:\n", pd.Series(y_train_smote).value_counts())
# Out:
# SMOTE balanced training set shape: (32710, 51)
# SMOTE balanced class distribution:
#  Class
# 0    16355
# 1    16355
# Name: count, dtype: int64

# %%
# %% [markdown]
# ## 5. Split cWGAN‑GP Balanced Data (70% train / 30% test)

# %%
X_gan = df_gan.drop(columns=[target_col])
y_gan = df_gan[target_col]

X_train_gan, X_test_gan, y_train_gan, y_test_gan = train_test_split(
    X_gan, y_gan, test_size=0.3, random_state=42, stratify=y_gan
)

print(f"Train size: {X_train_gan.shape[0]}, Test size: {X_test_gan.shape[0]}")
print("Train class distribution:\n", y_train_gan.value_counts())
print("Test class distribution:\n", y_test_gan.value_counts())
# Out:
# Train size: 32709, Test size: 14019
# Train class distribution:
#  Class
# 1    16355
# 0    16354
# Name: count, dtype: int64
# Test class distribution:
#  Class
# 0    7010
# 1    7009
# Name: count, dtype: int64

# %%
# %% [markdown]
# ## 6. Train Models

# %%
# =====================================================================
# Model 1: Imbalanced Baseline (Default XGBoost)
# =====================================================================
print("\n" + "="*60)
print("MODEL 1: IMBALANCED BASELINE")
print("="*60)

best_imb = train_xgboost_default(
    X_train_imb.values, y_train_imb.values,
    X_test_imb.values, y_test_imb.values,
    scale_pos_weight=True
)
# Out:
# ============================================================
# MODEL 1: IMBALANCED BASELINE
# ============================================================
#   Default XGBoost trained (scale_pos_weight=3.52)

# %%
# =====================================================================
# Model 2: SMOTE Baseline (Default XGBoost)
# =====================================================================
print("\n" + "="*60)
print("MODEL 2: SMOTE BASELINE")
print("="*60)

# Convert SMOTE output back to DataFrame with feature names
X_train_smote = pd.DataFrame(X_train_smote, columns=X_train_imb.columns)

best_smote = train_xgboost_default(
    X_train_smote.values, y_train_smote,
    X_test_imb.values, y_test_imb.values,
    scale_pos_weight=False
)
# Out:
# ============================================================
# MODEL 2: SMOTE BASELINE
# ============================================================
#   Default XGBoost trained (scale_pos_weight=1.00)

# %%
# =====================================================================
# Model 3: cWGAN‑GP (Optuna‑tuned XGBoost with 5‑fold CV)
# =====================================================================
print("\n" + "="*60)
print("MODEL 3: cWGAN‑GP (PROPOSED)")
print("="*60)

best_gan, best_params_gan = train_xgboost_optuna(
    X_train_gan.values, y_train_gan.values,
    X_test_gan.values, y_test_gan.values,
    n_trials=50,
    cv_folds=5,
    random_state=42
)

# Save model for SHAP
joblib.dump(best_gan, '../models/xgb_cwgan_default_credit_balanced.pkl')
print("\n✅ Model saved to ../models/xgb_cwgan_default_credit_balanced.pkl")
# Out:
# [I 2026-05-14 11:41:28,060] A new study created in memory with name: no-name-bfe29e26-feef-47dd-859a-5e630cf2a580
# ============================================================
# MODEL 3: cWGAN‑GP (PROPOSED)
# ============================================================
#
#   Starting Optuna hyperparameter optimization
#   Trials: 50, CV folds: 5
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2026-05-14 11:41:30,664] Trial 0 finished with value: 0.9345611144587714 and parameters: {'n_estimators': 144, 'max_depth': 10, 'learning_rate': 0.1205712628744377, 'subsample': 0.8394633936788146, 'colsample_bytree': 0.6624074561769746, 'min_child_weight': 2, 'gamma': 0.2904180608409973, 'reg_alpha': 8.661761457749352, 'reg_lambda': 6.011150117432088}. Best is trial 0 with value: 0.9345611144587714.
# [I 2026-05-14 11:41:31,933] Trial 1 finished with value: 0.9346759501588948 and parameters: {'n_estimators': 227, 'max_depth': 3, 'learning_rate': 0.2708160864249968, 'subsample': 0.9329770563201687, 'colsample_bytree': 0.6849356442713105, 'min_child_weight': 2, 'gamma': 0.9170225492671691, 'reg_alpha': 3.0424224295953772, 'reg_lambda': 5.247564316322379}. Best is trial 1 with value: 0.9346759501588948.
# [I 2026-05-14 11:41:33,317] Trial 2 finished with value: 0.9364287158261888 and parameters: {'n_estimators': 158, 'max_depth': 5, 'learning_rate': 0.08012737503998542, 'subsample': 0.6557975442608167, 'colsample_bytree': 0.7168578594140873, 'min_child_weight': 4, 'gamma': 2.28034992108518, 'reg_alpha': 7.851759613930136, 'reg_lambda': 1.9967378215835974}. Best is trial 2 with value: 0.9364287158261888.
# [I 2026-05-14 11:41:35,213] Trial 3 finished with value: 0.9344956979885456 and parameters: {'n_estimators': 179, 'max_depth': 7, 'learning_rate': 0.011711509955524094, 'subsample': 0.8430179407605753, 'colsample_bytree': 0.6682096494749166, 'min_child_weight': 1, 'gamma': 4.7444276862666666, 'reg_alpha': 9.656320330745594, 'reg_lambda': 8.08397348116461}. Best is trial 2 with value: 0.9364287158261888.
# [I 2026-05-14 11:41:36,112] Trial 4 finished with value: 0.9347491665821851 and parameters: {'n_estimators': 126, 'max_depth': 3, 'learning_rate': 0.1024932221692416, 'subsample': 0.7760609974958406, 'colsample_bytree': 0.6488152939379115, 'min_child_weight': 5, 'gamma': 0.17194260557609198, 'reg_alpha': 9.093204020787821, 'reg_lambda': 2.587799816000169}. Best is trial 2 with value: 0.9364287158261888.
# [I 2026-05-14 11:41:37,544] Trial 5 finished with value: 0.9361401413886835 and parameters: {'n_estimators': 216, 'max_depth': 5, 'learning_rate': 0.05864129169696527, 'subsample': 0.8186841117373118, 'colsample_bytree': 0.6739417822102108, 'min_child_weight': 10, 'gamma': 3.8756641168055728, 'reg_alpha': 9.394989415641891, 'reg_lambda': 8.948273504276488}. Best is trial 2 with value: 0.9364287158261888.
# [I 2026-05-14 11:41:40,090] Trial 6 finished with value: 0.9363785743115647 and parameters: {'n_estimators': 200, 'max_depth': 10, 'learning_rate': 0.01351182947645082, 'subsample': 0.6783931449676581, 'colsample_bytree': 0.6180909155642152, 'min_child_weight': 4, 'gamma': 1.9433864484474102, 'reg_alpha': 2.713490317738959, 'reg_lambda': 8.287375091519294}. Best is trial 2 with value: 0.9364287158261888.
# [I 2026-05-14 11:41:41,250] Trial 7 finished with value: 0.9359754143399108 and parameters: {'n_estimators': 139, 'max_depth': 5, 'learning_rate': 0.06333268775321843, 'subsample': 0.6563696899899051, 'colsample_bytree': 0.9208787923016158, 'min_child_weight': 1, 'gamma': 4.9344346830025865, 'reg_alpha': 7.722447692966574, 'reg_lambda': 1.987156815341724}. Best is trial 2 with value: 0.9364287158261888.
# [I 2026-05-14 11:41:42,327] Trial 8 finished with value: 0.9362040435038794 and parameters: {'n_estimators': 51, 'max_depth': 9, 'learning_rate': 0.11069143219393454, 'subsample': 0.8916028672163949, 'colsample_bytree': 0.9085081386743783, 'min_child_weight': 1, 'gamma': 1.7923286427213632, 'reg_alpha': 1.1586905952512971, 'reg_lambda': 8.631034258755935}. Best is trial 2 with value: 0.9364287158261888.
# [I 2026-05-14 11:41:44,076] Trial 9 finished with value: 0.9330773714230057 and parameters: {'n_estimators': 206, 'max_depth': 5, 'learning_rate': 0.012413189635294229, 'subsample': 0.7243929286862649, 'colsample_bytree': 0.7300733288106989, 'min_child_weight': 8, 'gamma': 3.1877873567760657, 'reg_alpha': 8.872127425763265, 'reg_lambda': 4.722149251619493}. Best is trial 2 with value: 0.9364287158261888.
# [I 2026-05-14 11:41:46,783] Trial 10 finished with value: 0.9368422701360671 and parameters: {'n_estimators': 287, 'max_depth': 7, 'learning_rate': 0.02847748683027988, 'subsample': 0.6071847502459279, 'colsample_bytree': 0.8010124870699186, 'min_child_weight': 7, 'gamma': 2.7609772566759423, 'reg_alpha': 6.240835271723653, 'reg_lambda': 0.39907535719484843}. Best is trial 10 with value: 0.9368422701360671.
# [I 2026-05-14 11:41:49,453] Trial 11 finished with value: 0.936919248063709 and parameters: {'n_estimators': 299, 'max_depth': 7, 'learning_rate': 0.0262209763647716, 'subsample': 0.6097132653988919, 'colsample_bytree': 0.8142497056141959, 'min_child_weight': 7, 'gamma': 2.8244956700380084, 'reg_alpha': 6.162117394629038, 'reg_lambda': 0.04675281541430032}. Best is trial 11 with value: 0.936919248063709.
# [I 2026-05-14 11:41:52,013] Trial 12 finished with value: 0.936808260259601 and parameters: {'n_estimators': 292, 'max_depth': 7, 'learning_rate': 0.026588373306819242, 'subsample': 0.6050785532559382, 'colsample_bytree': 0.8374709757162002, 'min_child_weight': 7, 'gamma': 3.138214726279749, 'reg_alpha': 5.4442375935611205, 'reg_lambda': 0.03107216487901537}. Best is trial 11 with value: 0.936919248063709.
# [I 2026-05-14 11:41:54,597] Trial 13 finished with value: 0.9369356579609951 and parameters: {'n_estimators': 300, 'max_depth': 8, 'learning_rate': 0.029397902514525866, 'subsample': 0.601375542364388, 'colsample_bytree': 0.8089266477456655, 'min_child_weight': 7, 'gamma': 3.2163885951985125, 'reg_alpha': 5.7425358570613945, 'reg_lambda': 0.1838031618356189}. Best is trial 13 with value: 0.9369356579609951.
# [I 2026-05-14 11:41:56,699] Trial 14 finished with value: 0.9367538062272434 and parameters: {'n_estimators': 257, 'max_depth': 8, 'learning_rate': 0.03269230106309387, 'subsample': 0.9984067957444853, 'colsample_bytree': 0.9976041524297954, 'min_child_weight': 9, 'gamma': 3.954509162058642, 'reg_alpha': 4.026769699735059, 'reg_lambda': 3.465343405040523}. Best is trial 13 with value: 0.9369356579609951.
# [I 2026-05-14 11:41:59,530] Trial 15 finished with value: 0.9365689419922301 and parameters: {'n_estimators': 261, 'max_depth': 8, 'learning_rate': 0.020219877080138386, 'subsample': 0.7495910822966338, 'colsample_bytree': 0.845481622898726, 'min_child_weight': 6, 'gamma': 3.759655798088267, 'reg_alpha': 6.705451426048862, 'reg_lambda': 1.1749375561260536}. Best is trial 13 with value: 0.9369356579609951.
# [I 2026-05-14 11:42:03,616] Trial 16 finished with value: 0.9367316107494709 and parameters: {'n_estimators': 255, 'max_depth': 8, 'learning_rate': 0.04002349498387789, 'subsample': 0.7114652779980589, 'colsample_bytree': 0.7727648795529052, 'min_child_weight': 8, 'gamma': 1.5485038985835824, 'reg_alpha': 4.691726864186297, 'reg_lambda': 3.583902847905419}. Best is trial 13 with value: 0.9369356579609951.
# [I 2026-05-14 11:42:07,220] Trial 17 finished with value: 0.9365397526939937 and parameters: {'n_estimators': 298, 'max_depth': 6, 'learning_rate': 0.019429709427516668, 'subsample': 0.6244913572475406, 'colsample_bytree': 0.8758697700847069, 'min_child_weight': 6, 'gamma': 2.883884076494262, 'reg_alpha': 6.322702980353724, 'reg_lambda': 1.1192046736169603}. Best is trial 13 with value: 0.9369356579609951.
# [I 2026-05-14 11:42:08,744] Trial 18 finished with value: 0.936516260889673 and parameters: {'n_estimators': 101, 'max_depth': 9, 'learning_rate': 0.04365957329198249, 'subsample': 0.6601589208140085, 'colsample_bytree': 0.7742830835268095, 'min_child_weight': 10, 'gamma': 3.6277148318110717, 'reg_alpha': 4.070899689188936, 'reg_lambda': 3.182071518694065}. Best is trial 13 with value: 0.9369356579609951.
# [I 2026-05-14 11:42:11,510] Trial 19 finished with value: 0.9359777360651371 and parameters: {'n_estimators': 241, 'max_depth': 6, 'learning_rate': 0.01908567987127766, 'subsample': 0.699370255237497, 'colsample_bytree': 0.9634804553391483, 'min_child_weight': 8, 'gamma': 4.406543292954863, 'reg_alpha': 5.397222480435524, 'reg_lambda': 6.2082607415130076}. Best is trial 13 with value: 0.9369356579609951.
# [I 2026-05-14 11:42:13,937] Trial 20 finished with value: 0.9342269141702598 and parameters: {'n_estimators': 270, 'max_depth': 9, 'learning_rate': 0.18590112816357693, 'subsample': 0.7516818631642986, 'colsample_bytree': 0.8069410260856267, 'min_child_weight': 5, 'gamma': 2.4264282310125895, 'reg_alpha': 0.11620961627553239, 'reg_lambda': 9.938427850497087}. Best is trial 13 with value: 0.9369356579609951.
# [I 2026-05-14 11:42:17,019] Trial 21 finished with value: 0.9369010751459685 and parameters: {'n_estimators': 286, 'max_depth': 7, 'learning_rate': 0.028384751942895418, 'subsample': 0.6053391488974321, 'colsample_bytree': 0.803597834691931, 'min_child_weight': 7, 'gamma': 2.77198508053782, 'reg_alpha': 6.384645540173251, 'reg_lambda': 0.05669109863571095}. Best is trial 13 with value: 0.9369356579609951.
# [I 2026-05-14 11:42:19,574] Trial 22 finished with value: 0.9367448183302114 and parameters: {'n_estimators': 274, 'max_depth': 8, 'learning_rate': 0.04398189955114846, 'subsample': 0.6363478335564196, 'colsample_bytree': 0.7487308154685308, 'min_child_weight': 7, 'gamma': 3.215737558699472, 'reg_alpha': 7.284191629393655, 'reg_lambda': 0.7064311434205797}. Best is trial 13 with value: 0.9369356579609951.
# [I 2026-05-14 11:42:22,663] Trial 23 finished with value: 0.9366635104698817 and parameters: {'n_estimators': 298, 'max_depth': 6, 'learning_rate': 0.02535709091150935, 'subsample': 0.6073248792362045, 'colsample_bytree': 0.8397435262947716, 'min_child_weight': 9, 'gamma': 2.238158177883628, 'reg_alpha': 5.633535852644535, 'reg_lambda': 1.6804850544309842}. Best is trial 13 with value: 0.9369356579609951.
# [I 2026-05-14 11:42:25,349] Trial 24 finished with value: 0.9363681228838452 and parameters: {'n_estimators': 242, 'max_depth': 7, 'learning_rate': 0.01606325397685403, 'subsample': 0.6898059134321025, 'colsample_bytree': 0.8774357743765923, 'min_child_weight': 6, 'gamma': 1.319426191460382, 'reg_alpha': 6.849392515875064, 'reg_lambda': 0.14139395072139038}. Best is trial 13 with value: 0.9369356579609951.
# [I 2026-05-14 11:42:27,302] Trial 25 finished with value: 0.9362966686692834 and parameters: {'n_estimators': 280, 'max_depth': 4, 'learning_rate': 0.035940129108987084, 'subsample': 0.6377739022043656, 'colsample_bytree': 0.7760975920640389, 'min_child_weight': 7, 'gamma': 2.7209071036513124, 'reg_alpha': 4.609255619475456, 'reg_lambda': 1.1104817553867306}. Best is trial 13 with value: 0.9369356579609951.
# [I 2026-05-14 11:42:29,240] Trial 26 finished with value: 0.9360809280062515 and parameters: {'n_estimators': 183, 'max_depth': 8, 'learning_rate': 0.023746925547754826, 'subsample': 0.6009696736755776, 'colsample_bytree': 0.8058522721568522, 'min_child_weight': 9, 'gamma': 3.4454383656056304, 'reg_alpha': 7.988752970605418, 'reg_lambda': 2.231815637033503}. Best is trial 13 with value: 0.9369356579609951.
# [I 2026-05-14 11:42:31,255] Trial 27 finished with value: 0.9367383776238991 and parameters: {'n_estimators': 300, 'max_depth': 6, 'learning_rate': 0.052953958753617296, 'subsample': 0.6757704486063397, 'colsample_bytree': 0.8853704136126311, 'min_child_weight': 5, 'gamma': 4.252962209408482, 'reg_alpha': 5.972404496263933, 'reg_lambda': 0.06599340360762428}. Best is trial 13 with value: 0.9369356579609951.
# [I 2026-05-14 11:42:34,050] Trial 28 finished with value: 0.9360485863697872 and parameters: {'n_estimators': 239, 'max_depth': 9, 'learning_rate': 0.010100147138674007, 'subsample': 0.6338533978877807, 'colsample_bytree': 0.827203565473636, 'min_child_weight': 8, 'gamma': 2.8971321258193017, 'reg_alpha': 4.000769574338067, 'reg_lambda': 2.958805407892789}. Best is trial 13 with value: 0.9369356579609951.
# [I 2026-05-14 11:42:37,853] Trial 29 finished with value: 0.9366521002936263 and parameters: {'n_estimators': 276, 'max_depth': 10, 'learning_rate': 0.0326890099566654, 'subsample': 0.7237511563400068, 'colsample_bytree': 0.7099503724941822, 'min_child_weight': 4, 'gamma': 0.7291468281860416, 'reg_alpha': 8.396731260015116, 'reg_lambda': 4.1278271484023}. Best is trial 13 with value: 0.9369356579609951.
# [I 2026-05-14 11:42:38,771] Trial 30 finished with value: 0.933893337335966 and parameters: {'n_estimators': 61, 'max_depth': 7, 'learning_rate': 0.016656110171927148, 'subsample': 0.8595849191581004, 'colsample_bytree': 0.7511253059741596, 'min_child_weight': 3, 'gamma': 2.1886034622450072, 'reg_alpha': 3.116052668590998, 'reg_lambda': 6.6286958305876675}. Best is trial 13 with value: 0.9369356579609951.
# [I 2026-05-14 11:42:41,309] Trial 31 finished with value: 0.936864435256999 and parameters: {'n_estimators': 282, 'max_depth': 7, 'learning_rate': 0.028208251272200845, 'subsample': 0.6274395767302744, 'colsample_bytree': 0.8018621602637811, 'min_child_weight': 7, 'gamma': 2.6253043148598327, 'reg_alpha': 6.214742337504003, 'reg_lambda': 0.8063959859428453}. Best is trial 13 with value: 0.9369356579609951.
# [I 2026-05-14 11:42:43,986] Trial 32 finished with value: 0.9366168435430225 and parameters: {'n_estimators': 262, 'max_depth': 7, 'learning_rate': 0.02277186644774114, 'subsample': 0.6297792123152619, 'colsample_bytree': 0.8580542723631205, 'min_child_weight': 7, 'gamma': 2.6113473231849844, 'reg_alpha': 7.087072797397159, 'reg_lambda': 0.9721473461323813}. Best is trial 13 with value: 0.9369356579609951.
# [I 2026-05-14 11:42:46,664] Trial 33 finished with value: 0.9368945568769428 and parameters: {'n_estimators': 280, 'max_depth': 8, 'learning_rate': 0.029975969524784138, 'subsample': 0.6593800087235366, 'colsample_bytree': 0.8214710856735635, 'min_child_weight': 6, 'gamma': 3.3150529583181285, 'reg_alpha': 4.933282179152822, 'reg_lambda': 1.3631514663946778}. Best is trial 13 with value: 0.9369356579609951.
# [I 2026-05-14 11:42:48,569] Trial 34 finished with value: 0.93700817267853 and parameters: {'n_estimators': 231, 'max_depth': 8, 'learning_rate': 0.04757374960261342, 'subsample': 0.6600023066837749, 'colsample_bytree': 0.8248865124718612, 'min_child_weight': 6, 'gamma': 3.460851476459044, 'reg_alpha': 4.912149564249213, 'reg_lambda': 1.8332034266613038}. Best is trial 34 with value: 0.93700817267853.
# [I 2026-05-14 11:42:50,243] Trial 35 finished with value: 0.9367539007218768 and parameters: {'n_estimators': 224, 'max_depth': 9, 'learning_rate': 0.08254050154386512, 'subsample': 0.6706830746474431, 'colsample_bytree': 0.7844369658914845, 'min_child_weight': 6, 'gamma': 4.187798650036304, 'reg_alpha': 3.3098555707788697, 'reg_lambda': 1.6822169223715906}. Best is trial 34 with value: 0.93700817267853.
# [I 2026-05-14 11:42:51,688] Trial 36 finished with value: 0.9366121034857333 and parameters: {'n_estimators': 239, 'max_depth': 8, 'learning_rate': 0.1475279834159674, 'subsample': 0.7952615637188891, 'colsample_bytree': 0.750508736277802, 'min_child_weight': 5, 'gamma': 3.5013406102117637, 'reg_alpha': 5.441118325899979, 'reg_lambda': 0.587188835935141}. Best is trial 34 with value: 0.93700817267853.
# [I 2026-05-14 11:42:53,316] Trial 37 finished with value: 0.9366388532927233 and parameters: {'n_estimators': 161, 'max_depth': 6, 'learning_rate': 0.05071383682439223, 'subsample': 0.6507090183735171, 'colsample_bytree': 0.7006370428783895, 'min_child_weight': 8, 'gamma': 3.017575531787514, 'reg_alpha': 2.460682813522084, 'reg_lambda': 2.5023705466917265}. Best is trial 34 with value: 0.93700817267853.
# [I 2026-05-14 11:42:54,798] Trial 38 finished with value: 0.9363077117567107 and parameters: {'n_estimators': 201, 'max_depth': 8, 'learning_rate': 0.0797715515537887, 'subsample': 0.6191182999823451, 'colsample_bytree': 0.8609168159089545, 'min_child_weight': 4, 'gamma': 4.563021404480586, 'reg_alpha': 7.234365727360579, 'reg_lambda': 1.6968236079428578}. Best is trial 34 with value: 0.93700817267853.
# [I 2026-05-14 11:42:57,154] Trial 39 finished with value: 0.9364120617422624 and parameters: {'n_estimators': 221, 'max_depth': 7, 'learning_rate': 0.06504734206339409, 'subsample': 0.6856703730219489, 'colsample_bytree': 0.9140476227991607, 'min_child_weight': 6, 'gamma': 1.9063202040515403, 'reg_alpha': 4.383795820518073, 'reg_lambda': 6.997154359563419}. Best is trial 34 with value: 0.93700817267853.
# [I 2026-05-14 11:42:58,388] Trial 40 finished with value: 0.9358380125747614 and parameters: {'n_estimators': 185, 'max_depth': 10, 'learning_rate': 0.2974053007288462, 'subsample': 0.6485505831610261, 'colsample_bytree': 0.6472458401606359, 'min_child_weight': 3, 'gamma': 4.045855931324511, 'reg_alpha': 7.713354694655147, 'reg_lambda': 0.5346915501987942}. Best is trial 34 with value: 0.93700817267853.
# [I 2026-05-14 11:43:00,957] Trial 41 finished with value: 0.9369409747668126 and parameters: {'n_estimators': 286, 'max_depth': 8, 'learning_rate': 0.03468854665681042, 'subsample': 0.6584945704163924, 'colsample_bytree': 0.8220282035080793, 'min_child_weight': 6, 'gamma': 3.391031885664126, 'reg_alpha': 5.139226301280174, 'reg_lambda': 1.281120357783581}. Best is trial 34 with value: 0.93700817267853.
# [I 2026-05-14 11:43:04,241] Trial 42 finished with value: 0.9368053308030619 and parameters: {'n_estimators': 268, 'max_depth': 9, 'learning_rate': 0.0378296553229407, 'subsample': 0.6180736522311178, 'colsample_bytree': 0.8268615427339616, 'min_child_weight': 7, 'gamma': 3.635389676240753, 'reg_alpha': 5.916774187195846, 'reg_lambda': 2.1286635221015606}. Best is trial 34 with value: 0.93700817267853.
# [I 2026-05-14 11:43:06,522] Trial 43 finished with value: 0.9368264001252274 and parameters: {'n_estimators': 249, 'max_depth': 7, 'learning_rate': 0.04823794004803921, 'subsample': 0.6478637699484504, 'colsample_bytree': 0.8954495887929053, 'min_child_weight': 5, 'gamma': 2.444145491631236, 'reg_alpha': 4.930399685817343, 'reg_lambda': 5.06688942567046}. Best is trial 34 with value: 0.93700817267853.
# [I 2026-05-14 11:43:09,087] Trial 44 finished with value: 0.9369930025785018 and parameters: {'n_estimators': 285, 'max_depth': 8, 'learning_rate': 0.03381654504808707, 'subsample': 0.6033036316547564, 'colsample_bytree': 0.8584412838504795, 'min_child_weight': 6, 'gamma': 3.38717583524884, 'reg_alpha': 3.60103081378455, 'reg_lambda': 0.0156839702216928}. Best is trial 34 with value: 0.93700817267853.
# [I 2026-05-14 11:43:10,892] Trial 45 finished with value: 0.9367636021175574 and parameters: {'n_estimators': 288, 'max_depth': 8, 'learning_rate': 0.06957716085528518, 'subsample': 0.9658403716974487, 'colsample_bytree': 0.9390692105011629, 'min_child_weight': 6, 'gamma': 3.382184265839235, 'reg_alpha': 3.6944390826043176, 'reg_lambda': 0.5237929995587176}. Best is trial 34 with value: 0.93700817267853.
# [I 2026-05-14 11:43:13,349] Trial 46 finished with value: 0.9370490040694506 and parameters: {'n_estimators': 270, 'max_depth': 9, 'learning_rate': 0.03478990502233307, 'subsample': 0.7472974225950906, 'colsample_bytree': 0.8456842173208211, 'min_child_weight': 5, 'gamma': 3.804591185694533, 'reg_alpha': 2.6285369057678327, 'reg_lambda': 1.3632509938326816}. Best is trial 46 with value: 0.9370490040694506.
# [I 2026-05-14 11:43:15,962] Trial 47 finished with value: 0.936933134221728 and parameters: {'n_estimators': 250, 'max_depth': 10, 'learning_rate': 0.03421882650101462, 'subsample': 0.7604066515614722, 'colsample_bytree': 0.8641378077279515, 'min_child_weight': 4, 'gamma': 3.7669221827032198, 'reg_alpha': 2.3047217441046075, 'reg_lambda': 2.6641109352117422}. Best is trial 46 with value: 0.9370490040694506.
# [I 2026-05-14 11:43:17,791] Trial 48 finished with value: 0.9366331014331678 and parameters: {'n_estimators': 213, 'max_depth': 9, 'learning_rate': 0.05749396240491714, 'subsample': 0.7318027567338191, 'colsample_bytree': 0.8465552801984709, 'min_child_weight': 5, 'gamma': 4.006692012318573, 'reg_alpha': 1.5839922039975454, 'reg_lambda': 1.458994381779551}. Best is trial 46 with value: 0.9370490040694506.
# [I 2026-05-14 11:43:20,094] Trial 49 finished with value: 0.9370277943615463 and parameters: {'n_estimators': 268, 'max_depth': 9, 'learning_rate': 0.04227160974573519, 'subsample': 0.8199803110310856, 'colsample_bytree': 0.8942221580361639, 'min_child_weight': 3, 'gamma': 4.855312508453576, 'reg_alpha': 1.740447997570518, 'reg_lambda': 4.153517123946443}. Best is trial 46 with value: 0.9370490040694506.
#
#   Best CV AUC-ROC: 0.9370
#   Best hyperparameters:
#     n_estimators: 270
#     max_depth: 9
#     learning_rate: 0.03478990502233307
#     subsample: 0.7472974225950906
#     colsample_bytree: 0.8456842173208211
#     min_child_weight: 5
#     gamma: 3.804591185694533
#     reg_alpha: 2.6285369057678327
#     reg_lambda: 1.3632509938326816
#
# ✅ Model saved to ../models/xgb_cwgan_default_credit_balanced.pkl

# %%
# %% [markdown]
# ## 7. Evaluate All Models

# %%
# Build models dictionary for comparison
models_dict = {
    'Imbalanced': (best_imb, X_test_imb, y_test_imb),
    'SMOTE': (best_smote, X_test_imb, y_test_imb),
    'cWGAN-GP (Optuna)': (best_gan, X_test_gan, y_test_gan)
}

# Run comprehensive comparison
results_df = compare_all_models(models_dict)
# Out:
# ============================================================
# Imbalanced Performance
# ============================================================
# Threshold : 0.5000
# AUC-ROC     : 0.7741
# Recall      : 0.5982
# Precision   : 0.4685
# F1-score    : 0.5255
# Accuracy    : 0.7610
# ============================================================
# SMOTE Performance
# ============================================================
# Threshold : 0.5000
# AUC-ROC     : 0.7725
# Recall      : 0.3908
# Precision   : 0.6254
# F1-score    : 0.4810
# Accuracy    : 0.8134
# ============================================================
# cWGAN-GP (Optuna) Performance
# ============================================================
# Threshold : 0.5000
# AUC-ROC     : 0.9400
# Recall      : 0.8249
# Precision   : 0.9347
# F1-score    : 0.8764
# Accuracy    : 0.8837
# ============================================================
# FINAL COMPARISON TABLE
# ============================================================
#                    AUC-ROC  Recall  Precision  F1-score  Accuracy
# Model
# Imbalanced          0.7741  0.5982     0.4685    0.5255    0.7610
# SMOTE               0.7725  0.3908     0.6254    0.4810    0.8134
# cWGAN-GP (Optuna)   0.9400  0.8249     0.9347    0.8764    0.8837

# %%
# %% [markdown]
# ## 8. Detailed Classification Reports

# %%
print("\nImbalanced Model - Classification Report:")
print(classification_report(y_test_imb, best_imb.predict(X_test_imb), target_names=['Good', 'Bad']))

print("\nSMOTE Model - Classification Report:")
print(classification_report(y_test_imb, best_smote.predict(X_test_imb), target_names=['Good', 'Bad']))

print("\ncWGAN‑GP Model - Classification Report:")
print(classification_report(y_test_gan, best_gan.predict(X_test_gan), target_names=['Good', 'Bad']))
# Out:
# Imbalanced Model - Classification Report:
#               precision    recall  f1-score   support
#
#         Good       0.88      0.81      0.84      7009
#          Bad       0.47      0.60      0.53      1991
#
#     accuracy                           0.76      9000
#    macro avg       0.67      0.70      0.68      9000
# weighted avg       0.79      0.76      0.77      9000
#
#
# SMOTE Model - Classification Report:
#               precision    recall  f1-score   support
#
#         Good       0.84      0.93      0.89      7009
#          Bad       0.63      0.39      0.48      1991
#
#     accuracy                           0.81      9000
#    macro avg       0.73      0.66      0.68      9000
# weighted avg       0.80      0.81      0.80      9000
#
#
# cWGAN‑GP Model - Classification Report:
#               precision    recall  f1-score   support
#
#         Good       0.84      0.94      0.89      7010
#          Bad       0.93      0.82      0.88      7009
#
#     accuracy                           0.88     14019
#    macro avg       0.89      0.88      0.88     14019
# weighted avg       0.89      0.88      0.88     14019

# %%
# %% [markdown]
# ## 9. SHAP Explainability (KernelExplainer)



# Load model and data
model = joblib.load('../models/xgb_cwgan_default_credit_balanced.pkl')
X_test = pd.read_csv('../data/processed/default_credit_balanced_cwgan_improved.csv').drop('Class', axis=1)

# Run SHAP analysis
shap_values, explainer = shap_explain(
    model=model,
    X_train=X_train_gan.values,
    X_test=X_test.values,
    feature_names=X_test.columns.tolist(),
    max_display=20,
    save_path='../figures/shap',
    n_samples=1000
)

# Optional: Waterfall plot for a specific sample
shap_waterfall_plot(
    model=model,
    X_sample=X_test.values,
    feature_names=X_test.columns.tolist(),
    sample_idx=0,
    save_path='../figures/shap'
)
# Out:
# ============================================================
# SHAP EXPLAINABILITY ANALYSIS
# ============================================================
#
# Attempting TreeExplainer...
#   Booster config patched successfully.
#   TreeExplainer failed: could not convert string to float: '[5.0001526E-1]'
#   Falling back to KernelExplainer...
#   KernelExplainer created successfully.
#   Computing SHAP values for 1000 samples...
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   SHAP values computed. Shape: (1000, 51)
#
#   Generating SHAP bar plot...
#   Generating SHAP beeswarm plot...
#   Top 10 Most Important Features (by mean |SHAP value|):
#   --------------------------------------------------
#    1. PAY_0                                   : 0.0807
#    2. PAY_AMT2                                : 0.0507
#    3. PAY_AMT1                                : 0.0378
#    4. PAY_2                                   : 0.0340
#    5. BILL_AMT3                               : 0.0310
#    6. PAY_3                                   : 0.0174
#    7. BILL_AMT2                               : 0.0153
#    8. LIMIT_BAL                               : 0.0151
#    9. PAY_4                                   : 0.0145
#   10. BILL_AMT1                               : 0.0130
#
# ✅ SHAP analysis complete.
#
#   Generating SHAP waterfall plot for sample 0...
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# %% [markdown]
# ## 10. Statistical Significance Testing

# %%
# Define a simplified param grid for nested CV
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [3, 5],
    'learning_rate': [0.01, 0.1]
}

# Nested CV for each model
print("\nRunning nested cross‑validation...")
auc_imb, std_imb, scores_imb = nested_cv_evaluation(
    X_train_imb.values, y_train_imb.values, param_grid, inner_cv=5, outer_cv=10
)
auc_smote, std_smote, scores_smote = nested_cv_evaluation(
    X_train_smote, y_train_smote, param_grid, inner_cv=5, outer_cv=10
)
auc_gan, std_gan, scores_gan = nested_cv_evaluation(
    X_train_gan.values, y_train_gan.values, param_grid, inner_cv=5, outer_cv=10
)

print(f"\nImbalanced: AUC = {auc_imb:.4f} ± {std_imb:.4f}")
print(f"SMOTE:      AUC = {auc_smote:.4f} ± {std_smote:.4f}")
print(f"cWGAN‑GP:   AUC = {auc_gan:.4f} ± {std_gan:.4f}")

# Friedman test (all three models)
print("\nFriedman Test (all models):")
friedman_test([scores_imb, scores_smote, scores_gan])

# Wilcoxon test (cWGAN‑GP vs Imbalanced)
print("\nWilcoxon Test (cWGAN‑GP vs Imbalanced):")
wilcoxon_test(scores_gan, scores_imb)

# Wilcoxon test (cWGAN‑GP vs SMOTE)
print("\nWilcoxon Test (cWGAN‑GP vs SMOTE):")
wilcoxon_test(scores_gan, scores_smote)
# Out:
# Running nested cross‑validation...
#
# Imbalanced: AUC = 0.7815 ± 0.0096
# SMOTE:      AUC = 0.9334 ± 0.0057
# cWGAN‑GP:   AUC = 0.9361 ± 0.0050
#
# Friedman Test (all models):
# Friedman test statistic: 15.8000, p-value: 0.0004
#
# Wilcoxon Test (cWGAN‑GP vs Imbalanced):
# Wilcoxon test statistic: 0.0000, p-value: 0.0020
#
# Wilcoxon Test (cWGAN‑GP vs SMOTE):
# Wilcoxon test statistic: 14.0000, p-value: 0.1934
# (14.0, 0.193359375)
